# %% [markdown]
# <a href="https://colab.research.google.com/github/R-Amelia/Data-visualization/blob/main/Rizki_Amelia_Putri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%time
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
sns.set()
# %matplotlib inline
# Out:
# CPU times: user 1.48 s, sys: 180 ms, total: 1.66 s
# Wall time: 2.33 s

# %%
fordGB = pd.read_csv("fordgobike-tripdataFor201902.csv")

# %%
fordGB.head()
# Out:
#    duration_sec start_time end_time  start_station_id  \
# 0         52185    32:10.1  01:56.0              21.0
# 1         42521    53:21.8  42:03.1              23.0
# 2         61854    13:13.2  24:08.1              86.0
# 3         36490    54:26.0  02:36.8             375.0
# 4          1585    54:18.5  20:44.1               7.0
#
#                                  start_station_name  start_station_latitude  \
# 0  Montgomery St BART Station (Market St at 2nd St)               37.789625
# 1                     The Embarcadero at Steuart St               37.791464
# 2                           Market St at Dolores St               37.769305
# 3                           Grove St at Masonic Ave               37.774836
# 4                               Frank H Ogawa Plaza               37.804562
#
#    start_station_longitude  end_station_id  \
# 0              -122.400811            13.0
# 1              -122.391034            81.0
# 2              -122.426826             3.0
# ...

# %%
fordGB.tail()
# Out:
#         duration_sec start_time end_time  start_station_id  \
# 183411           271    00:20.6  04:52.1              24.0
# 183412           313    05:34.7  10:48.5              21.0
# 183413           141    06:05.5  08:27.2             278.0
# 183414           139    05:34.4  07:54.3             220.0
# 183415           271    00:20.6  04:52.1              24.0
#
#                                       start_station_name  \
# 183411                             Spear St at Folsom St
# 183412  Montgomery St BART Station (Market St at 2nd St)
# 183413                            The Alameda at Bush St
# 183414                       San Pablo Ave at MLK Jr Way
# 183415                             Spear St at Folsom St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 183411               37.789677              -122.390428            37.0
# 183412               37.789625              -122.400811            66.0
# ...

# %%
fordGB.shape
print(f"Jumlah Kolom : {fordGB.shape[1]}")
print(f"Jumlah Baris : {fordGB.shape[0]}")
# Out:
# Jumlah Kolom : 16
# Jumlah Baris : 183416

# %%
fordGB.isnull().sum()
# Out:
# duration_sec                  0
# start_time                    0
# end_time                      0
# start_station_id            197
# start_station_name          197
# start_station_latitude        0
# start_station_longitude       0
# end_station_id              197
# end_station_name            197
# end_station_latitude          0
# end_station_longitude         0
# bike_id                       0
# user_type                     0
# member_birth_year          8265
# member_gender              8265
# bike_share_for_all_trip       0
# dtype: int64

# %%
fordGB = fordGB.dropna(how="any", subset=["start_station_id"])
fordGB = fordGB.dropna(how="any", subset=["start_station_id"])
fordGB = fordGB.dropna(how="any", subset=["end_station_id"])
fordGB = fordGB.dropna(how="any", subset=["end_station_id"])
fordGB = fordGB.dropna(how="any", subset=["member_birth_year"])
fordGB = fordGB.dropna(how="any", subset=["member_birth_year"])

print(f"Jumlah Kolom : {fordGB.shape[1]}")
print(f"Jumlah Baris : {fordGB.shape[0]}")
# Out:
# Jumlah Kolom : 16
# Jumlah Baris : 174956

# %%
fordGB_copy = fordGB.copy()
print(f"Jumlah Kolom copy: {fordGB.shape[1]}")
print(f"Jumlah Baris copy: {fordGB.shape[0]}")
# Out:
# Jumlah Kolom copy: 16
# Jumlah Baris copy: 174956

# %%
fordGB_copy.describe(include="all")
# Out:
#          duration_sec start_time end_time  start_station_id  \
# count   165610.000000     165610   165610     165610.000000
# unique            NaN      35653    35642               NaN
# top               NaN    24:29.8  22:24.4               NaN
# freq              NaN         15       19               NaN
# mean       550.095840        NaN      NaN        138.262261
# std        304.148098        NaN      NaN        110.693774
# min         61.000000        NaN      NaN          3.000000
# 25%        314.000000        NaN      NaN         49.000000
# 50%        488.000000        NaN      NaN        104.000000
# 75%        731.000000        NaN      NaN        239.000000
# max       1487.000000        NaN      NaN        398.000000
#
#           start_station_name  start_station_latitude  start_station_longitude  \
# count                 165610           165610.000000            165610.000000
# unique                   329                     NaN                      NaN
# ...

# %%
plt.figure(figsize = (18,18))
plt.boxplot(fordGB_copy["duration_sec"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a3a2a6ca290>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a3a28d783a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a3a2cc7f5b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a3a28d788e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a3a28d78b80>],
#  'means': []}

# %%
# persamaan 1
Q1 = fordGB_copy["duration_sec"].quantile(0.25)
Q3 = fordGB_copy["duration_sec"].quantile(0.75)
IQR = Q3 - Q1

# persamaan 2
outlierQ3 = Q3 + 1.5 * IQR

# membuang data outlier
fordGB_copy = fordGB_copy[(fordGB_copy["duration_sec"] < outlierQ3)]
fordGB_copy["duration_sec"].describe()
# Out:
# count    163177.000000
# mean        537.150677
# std         287.153599
# min          61.000000
# 25%         311.000000
# 50%         482.000000
# 75%         717.000000
# max        1356.000000
# Name: duration_sec, dtype: float64

# %%
print(f"Jumlah Kolom copy: {fordGB.shape[1]}")
print(f"Jumlah Baris copy: {fordGB.shape[0]}")
# Out:
# Jumlah Kolom copy: 16
# Jumlah Baris copy: 174956

# %%
# persamaan 1
Q1 = fordGB_copy["member_birth_year"].quantile(0.25)
Q3 = fordGB_copy["member_birth_year"].quantile(0.75)
IQR = Q3 - Q1

# persamaan 2
outlierQ3 = Q3 + 1.5 * IQR

# membuang data outlier
fordGB_copy = fordGB_copy[(fordGB_copy["member_birth_year"] < outlierQ3)]
fordGB_copy["member_birth_year"].describe()
# Out:
# count    163177.000000
# mean       1984.844371
# std          10.025453
# min        1900.000000
# 25%        1980.000000
# 50%        1987.000000
# 75%        1992.000000
# max        2001.000000
# Name: member_birth_year, dtype: float64

# %%
plt.figure(figsize = (15,15))
plt.boxplot(fordGB_copy["member_birth_year"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a3a28dbf280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a3a28dbf7c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a3a28dbefe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a3a28dbfd00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a3a28dbffa0>],
#  'means': []}

# %%
fordGB_copy.describe(include="all")
# Out:
#          duration_sec start_time end_time  start_station_id  \
# count   163177.000000     163177   163177     163177.000000
# unique            NaN      35625    35608               NaN
# top               NaN    12:19.2  22:24.4               NaN
# freq              NaN         15       19               NaN
# mean       537.150677        NaN      NaN        138.243674
# std        287.153599        NaN      NaN        110.549835
# min         61.000000        NaN      NaN          3.000000
# 25%        311.000000        NaN      NaN         49.000000
# 50%        482.000000        NaN      NaN        104.000000
# 75%        717.000000        NaN      NaN        239.000000
# max       1356.000000        NaN      NaN        398.000000
#
#           start_station_name  start_station_latitude  start_station_longitude  \
# count                 163177           163177.000000            163177.000000
# unique                   329                     NaN                      NaN
# ...

# %%
fordGB_copy.duplicated()
# Out:
# 6         False
# 9         False
# 10        False
# 11        False
# 12        False
#           ...
# 183411    False
# 183412     True
# 183413     True
# 183414     True
# 183415     True
# Length: 163177, dtype: bool

# %%
fordGB_copy = fordGB_copy.drop_duplicates()
print(f"Jumlah Kolom copy: {fordGB.shape[1]}")
print(f"Jumlah Baris copy: {fordGB.shape[0]}")
# Out:
# Jumlah Kolom copy: 16
# Jumlah Baris copy: 174956
